# %%
import numpy as np
import pandas as pd
from sklearn.metrics import zero_one_loss
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss, roc_curve, roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD

# %%
# import data
df = pd.read_csv (r'bank-additional\bank-additional.csv', sep = ';', engine= 'python')
length = df.shape[0]
tussen = df[["y"]]
target = tussen.copy()
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)
df.head(10)
# Out:
#    age           job   marital            education  default  housing  \
# 0   30   blue-collar   married             basic.9y       no      yes
# 1   39      services    single          high.school       no       no
# 2   25      services   married          high.school       no      yes
# 3   38      services   married             basic.9y       no  unknown
# 4   47        admin.   married    university.degree       no      yes
# 5   32      services    single    university.degree       no       no
# 6   32        admin.    single    university.degree       no      yes
# 7   41  entrepreneur   married    university.degree  unknown      yes
# 8   31      services  divorced  professional.course       no       no
# 9   35   blue-collar   married             basic.9y  unknown       no
#
#       loan    contact month day_of_week  duration  campaign  pdays  previous  \
# 0       no   cellular   may         fri       487         2    999         0
# 1       no  telephone   may         fri       346         4    999         0
# 2       no  telephone   jun         wed       227         1    999         0
# 3  unknown  telephone   jun         fri        17         3    999         0
# 4       no   cellular   nov         mon        58         1    999         0
# 5       no   cellular   sep         thu       128         3    999         2
# 6       no   cellular   sep         mon       290         4    999         0
# 7       no   cellular   nov         mon        44         2    999         0
# 8       no   cellular   nov         tue        68         1    999         1
# 9       no  telephone   may         thu       170         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent          -1.8          92.893          -46.2      1.313
# 1  nonexistent           1.1          93.994          -36.4      4.855
# 2  nonexistent           1.4          94.465          -41.8      4.962
# 3  nonexistent           1.4          94.465          -41.8      4.959
# 4  nonexistent          -0.1          93.200          -42.0      4.191
# 5      failure          -1.1          94.199          -37.5      0.884
# 6  nonexistent          -1.1          94.199          -37.5      0.879
# 7  nonexistent          -0.1          93.200          -42.0      4.191
# 8      failure          -0.1          93.200          -42.0      4.153
# 9  nonexistent           1.1          93.994          -36.4      4.855
#
#    nr.employed
# 0       5099.1
# 1       5191.0
# 2       5228.1
# 3       5228.1
# 4       5195.8
# 5       4963.6
# 6       4963.6
# 7       5195.8
# 8       5195.8
# 9       5191.0

# %%
#Encoding all the categorical variables and deleting them from the old dataframe
categories = ['marital','education','default','housing','loan','contact','month','day_of_week','poutcome']
df_encoded = pd.get_dummies(df['job'], prefix='job', drop_first=False)
df_encoded.insert(0, 'ID', range(0, len(df_encoded)))
del df['job']

for x in categories:
    df_encoded_tussen = pd.get_dummies(df[x], prefix=x, drop_first=True)
    df_encoded_tussen.insert(0, 'ID', range(0, len(df_encoded_tussen)))
    df_encoded = pd.merge(df_encoded, df_encoded_tussen, on = 'ID', how = 'outer')
    del df[x]

df.insert(0, 'ID', range(0, len(df)))
features = pd.merge(df_encoded, df, on = 'ID', how = 'outer')
y = pd.get_dummies(target, drop_first=True)
del features['ID']

# %%
#Changing pandas dataframe to numpy array
X = features.values
y = y.values

# %%
#Normalizing the data
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
ohe = OneHotEncoder()
y = ohe.fit_transform(y).toarray()

# %%
train_features, test_features, train_targets, test_targets = train_test_split(X, y, test_size=0.2,
                                                                                  random_state=23)

# %%
# Neural network
model = Sequential()
model.add(Dense(16, input_dim=54, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='softmax'))

# %%
opt = SGD(lr=0.01)
model.compile(loss = "binary_crossentropy", optimizer = opt, metrics=['accuracy'])

# %%
history = model.fit(train_features, train_targets, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 52/52 [==============================] - 0s 813us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 2/100
# 52/52 [==============================] - 0s 698us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 3/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 4/100
# 52/52 [==============================] - 0s 794us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 5/100
# 52/52 [==============================] - 0s 635us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 6/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 7/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 8/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 9/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 10/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 11/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 12/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 13/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 14/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 15/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 16/100
# 52/52 [==============================] - 0s 612us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 17/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 18/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 19/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 20/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 21/100
# 52/52 [==============================] - 0s 635us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 22/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 23/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 24/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 25/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 26/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 27/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 28/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 29/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 30/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 31/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 32/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 33/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 34/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 35/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 36/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 37/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 38/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 39/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 40/100
# 52/52 [==============================] - 0s 654us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 41/100
# 52/52 [==============================] - 0s 673us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 42/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 43/100
# 52/52 [==============================] - 0s 692us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 44/100
# 52/52 [==============================] - 0s 692us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 45/100
# 52/52 [==============================] - 0s 660us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 46/100
# 52/52 [==============================] - 0s 639us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 47/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 48/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 49/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 50/100
# 52/52 [==============================] - 0s 692us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 51/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 52/100
# 52/52 [==============================] - 0s 731us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 53/100
# 52/52 [==============================] - 0s 654us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 54/100
# 52/52 [==============================] - 0s 731us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 55/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 56/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 57/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 58/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 59/100
# 52/52 [==============================] - 0s 673us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 60/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 61/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 62/100
# 52/52 [==============================] - 0s 635us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 63/100
# 52/52 [==============================] - 0s 635us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 64/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 65/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 66/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 67/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 68/100
# 52/52 [==============================] - 0s 673us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 69/100
# 52/52 [==============================] - 0s 712us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 70/100
# 52/52 [==============================] - 0s 679us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 71/100
# 52/52 [==============================] - 0s 692us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 72/100
# 52/52 [==============================] - 0s 731us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 73/100
# 52/52 [==============================] - 0s 685us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 74/100
# 52/52 [==============================] - 0s 692us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 75/100
# 52/52 [==============================] - 0s 616us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 76/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 77/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 78/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 79/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 80/100
# 52/52 [==============================] - 0s 542us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 81/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 82/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 83/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 84/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 85/100
# 52/52 [==============================] - 0s 596us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 86/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 87/100
# 52/52 [==============================] - 0s 561us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 88/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 89/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 90/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 91/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 92/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 93/100
# 52/52 [==============================] - 0s 539us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 94/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 95/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 96/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 97/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 98/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 99/100
# 52/52 [==============================] - 0s 558us/step - loss: 7.6246 - accuracy: 0.5000
# Epoch 100/100
# 52/52 [==============================] - 0s 577us/step - loss: 7.6246 - accuracy: 0.5000

# %%
predictions = model.predict(test_features)

print("Confusion Matrix:")
print(confusion_matrix(test_targets, predictions))

print("Classification Report")
print(classification_report(test_targets, predictions))
    
#Beginning the plotting of ROC-curve
pred_prob = model.predict_proba(test_features)
fpr, tpr, thresh = roc_curve(test_targets, pred_prob[:,1], pos_label=1)
   
#Plot roc curves
plt.plot(fpr, tpr, linestyle='--',color='orange', label='Boosted Trees')

# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
    
#AUC Score
auc_score = roc_auc_score(test_targets, pred_prob[:,1])
print("AUC Score: " + str(np.round(auc_score , 3)))
    
#Log-loss function
print("Log-Loss: " + str(np.round(log_loss(test_targets, predictions),3)))
# Out:
# Confusion Matrix:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7132\3213714233.py in <module>
#       2
#       3 print("Confusion Matrix:")
# ----> 4 print(confusion_matrix(test_targets, predictions))
#       5
#       6 print("Classification Report")
#
# ~\anaconda3\envs\marketingseminar\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\envs\marketingseminar\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
# ---> 95                 type_true, type_pred
#      96             )
#      97         )
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and binary targets

# %%
a = accuracy_score(pred,test)
print('Accuracy is:', a*100)

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss']) plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()
