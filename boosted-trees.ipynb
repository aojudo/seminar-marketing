# %% [markdown]
# # Boosted trees

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import zero_one_loss
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import log_loss, roc_curve, roc_auc_score
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot
from sklearn.metrics import accuracy_score
from imblearn.under_sampling import NearMiss
from sklearn.model_selection import GridSearchCV
from imblearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import KFold
import time

# %% [markdown]
# ## Data preperation

# %%
#Reading the file and splitting our target column
df = pd.read_csv (r'bank-additional-full.csv', sep = ';', engine= 'python')   

tussen = df[["y"]]
target = tussen.copy()
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)

df=df[['age','default', 'contact', 'month', 'previous', 'poutcome', 'emp.var.rate', 'euribor3m', 'nr.employed']]

#Encoding all the catergorical variables and deleting them from the old dataframe
categories = ['contact','month','poutcome']
df_encoded = pd.get_dummies(df['default'], prefix='default', drop_first=True)
df_encoded.insert(0, 'ID', range(0, len(df_encoded)))
del df['default']

for x in categories:
    df_encoded_tussen = pd.get_dummies(df[x], prefix=x, drop_first=True)
    df_encoded_tussen.insert(0, 'ID', range(0, len(df_encoded_tussen)))
    df_encoded = pd.merge(df_encoded, df_encoded_tussen, on = 'ID', how = 'outer')
    del df[x]

df.insert(0, 'ID', range(0, len(df)))
features = pd.merge(df_encoded, df, on = 'ID', how = 'outer')
y = pd.get_dummies(target, drop_first=True)
del features['ID']

# %%
# seperate training from testing data
train_features, test_features, train_targets, test_targets = train_test_split(features, y.values.ravel(), test_size=0.2,
                                                                                  random_state=23)

# %% [markdown]
# ## Grid search hyperparameter tuning

# %%
# define hyperparameter search space
learning_rate = [0.1, 0.01, pow(10,-3), pow(10,-4), pow(10,-5), pow(10,-6)] 
max_depth = [1,2,3,4,5,6,7,8]
n_estimators = range(1,5002, 1000)

# create dictionary from search space
grid = dict(
    gradientboostingclassifier__max_depth=max_depth,
    gradientboostingclassifier__learning_rate=learning_rate,
    gradientboostingclassifier__n_estimators=n_estimators,
)

# create 10-fold cross validation generator
cv = KFold(n_splits=10, shuffle = True, random_state=23)

# create imbalanced learn pipeline
imba_pipeline = make_pipeline(NearMiss(version=1), GradientBoostingClassifier(max_depth=1, 
                                                                                 learning_rate = 0.1,
                                          n_estimators= 123 ,random_state=23))

# create random searcher with 10-fold cv and start tuning process
model_grid = GridSearchCV(estimator=imba_pipeline, param_grid=grid, n_jobs=1, cv=cv, verbose=2, scoring='roc_auc')
grid_res = model_grid.fit(train_features, train_targets)

# summarise grid search info
bestScore = grid_res.best_score_
bestParams = grid_res.best_params_
print("[INFO] best score is {:.2f} using {}".format(bestScore,
    bestParams))
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   4.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   4.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   3.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   3.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   4.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   5.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   5.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   4.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   6.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=1001; total time=   5.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   7.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   7.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=2001; total time=   6.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   9.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   9.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=3001; total time=   7.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  11.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=4001; total time=  10.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  11.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  13.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=1, gradientboostingclassifier__n_estimators=5001; total time=  12.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   4.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   4.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=1001; total time=   5.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=2001; total time=   8.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=3001; total time=  11.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  15.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=4001; total time=  14.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  17.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  18.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=2, gradientboostingclassifier__n_estimators=5001; total time=  18.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1; total time=   1.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=1001; total time=   6.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=2001; total time=  10.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  15.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  15.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=3001; total time=  14.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  19.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  18.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  19.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  18.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=4001; total time=  20.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  26.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  24.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  24.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=3, gradientboostingclassifier__n_estimators=5001; total time=  25.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   2.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   2.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1; total time=   2.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   8.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   7.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=1001; total time=   8.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  14.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=2001; total time=  13.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  20.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  20.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  20.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  19.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=3001; total time=  20.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  26.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=4001; total time=  25.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  32.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=4, gradientboostingclassifier__n_estimators=5001; total time=  31.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   2.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   2.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=1001; total time=   9.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.5s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=2001; total time=  16.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  24.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  23.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  24.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  24.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  23.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  23.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  23.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  23.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  24.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=3001; total time=  24.1s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  30.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  32.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.6s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.2s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.0s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  30.9s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=4001; total time=  31.4s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=5001; total time=  38.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=5001; total time=  38.7s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=5001; total time=  39.3s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=5001; total time=  38.8s
# [CV] END gradientboostingclassifier__learning_rate=0.1, gradientboostingclassifier__max_depth=5, gradientboostingclassifier__n_estimators=5001; total time=  38.3s
# ...
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  20.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  20.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  19.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  21.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  20.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=2001; total time=  20.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  29.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  29.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  31.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  28.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=3001; total time=  30.1s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  39.1s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  40.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  37.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  41.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  39.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  39.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  42.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  41.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  40.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=4001; total time=  39.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  49.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  49.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  46.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  49.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  48.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  49.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  46.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  50.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  49.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=7, gradientboostingclassifier__n_estimators=5001; total time=  48.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   2.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1; total time=   1.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  13.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  13.1s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=1001; total time=  12.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  24.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  22.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  22.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  23.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=2001; total time=  24.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  34.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  34.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  32.9s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  35.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  34.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  33.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  32.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  34.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  35.1s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=3001; total time=  34.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  45.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  45.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  42.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  46.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  45.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  45.5s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  43.6s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  46.2s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  46.3s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=4001; total time=  45.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  56.1s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  56.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  54.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  57.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  56.4s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  55.8s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  53.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  56.7s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  59.0s
# [CV] END gradientboostingclassifier__learning_rate=1e-06, gradientboostingclassifier__max_depth=8, gradientboostingclassifier__n_estimators=5001; total time=  56.8s
# [INFO] best score is 0.76 using {'gradientboostingclassifier__learning_rate': 0.001, 'gradientboostingclassifier__max_depth': 1, 'gradientboostingclassifier__n_estimators': 1001}

# %% [markdown]
# ## Undersample training data for further analysis

# %%
# underfit training data using nearmiss 1
nm = NearMiss(version = 1)
x_res, y_res = nm.fit_resample(train_features, train_targets)
train_features.shape,x_res.shape
# Out:
# ((32950, 19), (7506, 19))

# %% [markdown]
# ## Overfit Analysis

# %%
#Now we set our n_estimator and learning_rate to the optimal value found in the last grid search
learningRate = 0.001
nEstimator = 1001
maximumDepth = 1

# %% [markdown]
# #### Check for overfitting by varying n_estimators

# %%
# define lists to collect scores
train_scores, test_scores = list(), list()

# define the estimators to evaluate
values = [i for i in range(1, 6001, 1000)]
# evaluate a decision tree for estimator
for i in values:
    # configure the model
    model = GradientBoostingClassifier(max_depth=maximumDepth, learning_rate = learningRate, n_estimators=i, random_state=23).fit(
        x_res, y_res)
    # evaluate on the train dataset
    schatting = model.predict(x_res)
    train_acc = roc_auc_score(y_res, schatting)
    train_scores.append(train_acc)
    # evaluate on the test dataset
    test_schatting = model.predict(test_features)
    test_acc = roc_auc_score(test_targets, test_schatting)
    test_scores.append(test_acc)
    # summarize progress
    print('n_estimator: %.0f, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs n_estimator
pyplot.plot(values, train_scores, '-o', label='Train')
pyplot.plot(values, test_scores, '-o', label='Test')
plt.ylabel('AUC')
plt.xlabel('n_estimators')
pyplot.legend()
pyplot.show()
# Out:
# n_estimator: 1, train: 0.797, test: 0.702
# n_estimator: 1001, train: 0.799, test: 0.688
# n_estimator: 2001, train: 0.798, test: 0.686
# n_estimator: 3001, train: 0.809, test: 0.684
# n_estimator: 4001, train: 0.814, test: 0.676
# n_estimator: 5001, train: 0.817, test: 0.670

# %% [markdown]
# #### Check for overfitting by varying max_depth

# %%
# define lists to collect scores
train_scores, test_scores = list(), list()

# define the estimators to evaluate
values = [1,2,3,4,5,6,7,8]
# evaluate a decision tree for estimator
for i in values:
    # configure the model
    model = GradientBoostingClassifier(max_depth=i, learning_rate = learningRate, n_estimators=nEstimator, random_state=23).fit(
        x_res, y_res)
    # evaluate on the train dataset
    schatting = model.predict(x_res)
    train_acc = roc_auc_score(y_res, schatting)
    train_scores.append(train_acc)
    # evaluate on the test dataset
    test_schatting = model.predict(test_features)
    test_acc = roc_auc_score(test_targets, test_schatting)
    test_scores.append(test_acc)
    # summarize progress
    print('tree depth: %.0f, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs n_estimator
pyplot.plot(values, train_scores, '-o', label='Train')
pyplot.plot(values, test_scores, '-o', label='Test')
plt.ylabel('AUC')
plt.xlabel('max_depth')
pyplot.legend()
pyplot.show()
# Out:
# tree depth: 1, train: 0.799, test: 0.688
# tree depth: 2, train: 0.813, test: 0.680
# tree depth: 3, train: 0.832, test: 0.644
# tree depth: 4, train: 0.855, test: 0.629
# tree depth: 5, train: 0.872, test: 0.615
# tree depth: 6, train: 0.881, test: 0.604
# tree depth: 7, train: 0.892, test: 0.596
# tree depth: 8, train: 0.897, test: 0.590

# %%
#Check for overfitting with learning_rate
# define lists to collect scores
train_scores, test_scores = list(), list()

# define the estimators to evaluate
values = [0.1, 0.01, pow(10,-3), pow(10,-4), pow(10,-5), pow(10,-6)]
# evaluate a decision tree for estimator
for i in values:
    # configure the model
    model = GradientBoostingClassifier(max_depth=maximumDepth, learning_rate = i, n_estimators=nEstimator, random_state=23).fit(
        x_res, y_res)
    # evaluate on the train dataset
    schatting = model.predict(x_res)
    train_acc = roc_auc_score(y_res, schatting)
    train_scores.append(train_acc)
    # evaluate on the test dataset
    test_schatting = model.predict(test_features)
    test_acc = roc_auc_score(test_targets, test_schatting)
    test_scores.append(test_acc)
    # summarize progress
    print('Learning rate: %.6f, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
# plot of train and test scores vs n_estimator
pyplot.plot(values, train_scores, '-o', label='Train')
pyplot.plot(values, test_scores, '-o', label='Test')
plt.ylabel('AUC')
plt.xlabel('learning_rate')
pyplot.legend()
pyplot.show()
# Out:
# Learning rate: 0.100000, train: 0.858, test: 0.620
# Learning rate: 0.010000, train: 0.813, test: 0.645
# Learning rate: 0.001000, train: 0.799, test: 0.688
# Learning rate: 0.000100, train: 0.797, test: 0.702
# Learning rate: 0.000010, train: 0.797, test: 0.702
# Learning rate: 0.000001, train: 0.797, test: 0.702

# %% [markdown]
# ## Run final model on test data to get AUC

# %%
#Boosting the tree and predicting with ROC curve and classification reports

# for model timing
print(time.ctime())

ensemble = GradientBoostingClassifier(max_depth=maximumDepth, learning_rate = learningRate,
                                          n_estimators= nEstimator ,random_state=23)
    
k = 10
kf = KFold(n_splits=k, shuffle = True, random_state=23)

dt_scores = cross_val_score(ensemble, x_res, y_res, scoring ='roc_auc' ,cv = kf)
print("mean cross validation score: {}".format(np.round(np.mean(dt_scores),3)))

ensemble.fit(x_res, y_res)
predictions = ensemble.predict(test_features)
    
print("Confusion Matrix:")
print(confusion_matrix(test_targets, predictions))

print("Classification Report")
print(classification_report(test_targets, predictions))
    
#Beginning the plotting of ROC-curve
pred_prob = ensemble.predict_proba(test_features)
fpr, tpr, thresh = roc_curve(test_targets, pred_prob[:,1], pos_label=1)
    
#Plot roc curves
plt.plot(fpr, tpr, linestyle='--',color='orange', label='Boosted Trees')

# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=300)
plt.show();
    
#AUC Score
auc_score = roc_auc_score(test_targets, pred_prob[:,1])
print("AUC Score: " + str(np.round(auc_score , 3)))

# for model timing
print(time.ctime())
# Out:
# Mon Apr 18 21:02:36 2022
# mean cross validation score: 0.839
# Confusion Matrix:
# [[4559 2792]
#  [ 217  670]]
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.62      0.75      7351
#            1       0.19      0.76      0.31       887
#
#     accuracy                           0.63      8238
#    macro avg       0.57      0.69      0.53      8238
# weighted avg       0.87      0.63      0.70      8238
# AUC Score: 0.75
# Mon Apr 18 21:03:03 2022
